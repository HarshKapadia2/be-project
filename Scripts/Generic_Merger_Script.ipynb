# %%
import pandas as pd
import numpy as np

# %%
dataset_bowlers = pd.read_excel('merged.xlsx','Bowlers')
dataset_batsmen = pd.read_excel('merged.xlsx','Batsmen')
dataset_auction = pd.read_excel('../dataset_2019.xlsx','Auction')

# %%
auction_names=dataset_auction.iloc[:,0].values
auction_values=dataset_auction.iloc[:,1].values

batsmen_values=dataset_batsmen.iloc[:,:].values
bowlers_values=dataset_bowlers.iloc[:,:].values

# %%
dataset_bowlers
# Out:
#                   Player     Ov  Wkts     Avg    Econ      SR
# 0      Bhuvneshwar Kumar  49.15  17.5  26.760   7.355  21.420
# 1         Jaydev Unadkat  47.85  17.5  28.795   8.335  19.450
# 2         Jasprit Bumrah  56.60  18.5  21.915   7.135  18.425
# 3   Mitchell McClenaghan  47.00  16.5  25.195   8.840  17.095
# 4            Imran Tahir  33.70  12.0  25.915   8.470  18.160
# ..                   ...    ...   ...     ...     ...     ...
# 58       Shakib Al Hasan  30.00   7.0  16.285   9.165  12.210
# 59     Mustafizur Rahman  14.85   3.5  16.425  10.555  11.785
# 60         Anureet Singh   3.00   0.5  21.000  11.750  12.000
# 61         Barinder Sran  12.00   2.0  28.625  12.450  16.500
# 62          Ankit Sharma   1.00   0.0   0.000  13.500   0.000
#
# [63 rows x 6 columns]

# %%
auction_names=[i.split('[')[0].lower() for i in auction_names]

# %%
prices_dict={auction_names[i]:auction_values[i] for i in range(len(auction_names))}
prices_dict
# Out:
# {'quinton de kock': 280,
#  'mandeep singh': 140,
#  'marcus stoinis': 620,
#  'shikhar dhawan': 520,
#  'vijay shankar': 320,
#  'shahbaz nadeem': 320,
#  'abhishek sharma': 55,
#  'mahendra singh dhoni': 1500,
#  'suresh raina': 1100,
#  'kedar jadhav': 780,
#  'ravindra jadeja': 700,
#  'dwayne bravo': 640,
#  'karn sharma': 500,
#  'shane watson': 400,
#  'shardul thakur': 260,
#  'ambati rayudu': 220,
#  'david willey': 200,
#  'harbhajan singh': 200,
#  'murali vijay': 200,
#  'faf du plessis': 160,
#  'imran tahir': 100,
#  'sam billings': 100,
#  'deepak chahar': 80,
#  'lungi ngidi': 50,
#  'mitchell santner': 50,
#  'km asif': 40,
#  'chaitanya bishnoi': 20,
#  'dhruv shorey': 20,
#  'monu singh': 20,
#  'narayan jagadeesan': 20,
#  'rishabh pant': 800,
#  'chris morris': 710,
#  'shreyas iyer': 700,
#  'kagiso rabada': 420,
#  'amit mishra': 400,
#  'rahul tewatia': 300,
#  'trent boult': 220,
#  'colin munro': 190,
#  'prithvi shaw': 120,
#  'avesh khan': 70,
#  'jayant yadav': 50,
#  'harshal patel': 20,
#  'manjot kalra': 20,
#  'sandeep lamichhane': 20,
#  'kl rahul': 1100,
#  'ravichandran ashwin': 760,
#  'andrew tye': 720,
#  'karun nair': 560,
#  'mujeeb ur rahman': 400,
#  'ankit rajpoot': 300,
#  'david miller': 300,
#  'chris gayle': 200,
#  'mayank agarwal': 100,
#  'sunil narine': 850,
#  'chris lynn': 960,
#  'andre russell': 700,
#  'dinesh karthik': 740,
#  'robin uthappa': 640,
#  'kuldeep yadav': 580,
#  'piyush chawla': 420,
#  'nitish rana': 340,
#  'kamlesh nagarkoti': 320,
#  'shivam mavi': 300,
#  'shubman gill': 180,
#  'rinku singh': 80,
#  'prasidh krishna': 20,
#  'rohit sharma': 1500,
#  'hardik pandya': 1100,
#  'krunal pandya': 880,
#  'jasprit bumrah': 700,
#  'ishan kishan': 620,
#  'kieron pollard': 540,
#  'evin lewis': 380,
#  'suryakumar yadav': 320,
#  'ben cutting': 220,
#  'rahul chahar': 190,
#  'jason behrendorff': 150,
#  'mitchell mcclenaghan': 100,
#  'adam milne': 75,
#  'aditya tare': 20,
#  'anukul roy': 20,
#  'mayank markande': 20,
#  'siddhesh lad': 20,
#  'ben stokes': 1250,
#  'steve smith': 1200,
#  'sanju samson': 800,
#  'jofra archer': 720,
#  'krishnappa gowtham': 620,
#  'jos buttler': 440,
#  'ajinkya rahane': 400,
#  'rahul tripathi': 340,
#  'dhawal kulkarni': 75,
#  'ish sodhi': 50,
#  'stuart binny': 50,
#  'aryaman birla': 30,
#  'mahipal lomror': 20,
#  'prashant chopra': 20,
#  'shreyas gopal': 20,
#  'sudhesan midhun': 20,
#  'virat kohli': 1700,
#  'ab de villiers': 1100,
#  'yuzvendra chahal': 600,
#  'umesh yadav': 420,
#  'washington sundar': 320,
#  'navdeep saini': 300,
#  'mohammed siraj': 260,
#  'colin de grandhomme': 220,
#  'nathan coulter-nile': 220,
#  'moeen ali': 170,
#  'parthiv patel': 170,
#  'pawan negi': 100,
#  'tim southee': 100,
#  'kulwant khejroliya': 85,
#  'david warner': 1200,
#  'manish pandey': 1100,
#  'rashid khan': 900,
#  'bhuvneshwar kumar': 850,
#  'siddarth kaul': 380,
#  'deepak hooda': 360,
#  'kane williamson': 300,
#  'khaleel ahmed': 300,
#  'sandeep sharma': 300,
#  'shakib al hasan': 200,
#  'yusuf pathan': 190,
#  'mohammad nabi': 100,
#  'shreevats goswami': 100,
#  'basil thampi': 95,
#  'billy stanlake': 50,
#  'thangarasu natarajan': 40,
#  'ricky bhui': 20,
#  'hanuma vihari': 200,
#  'shimron hetmyer': 420,
#  'carlos brathwaite': 500,
#  'gurkeerat singh': 50,
#  'moises henriques': 100,
#  'axar patel': 500,
#  'jonny bairstow': 220,
#  'nicholas pooran': 420,
#  'wriddhiman saha': 120,
#  'jaydev unadkat': 840,
#  'ishant sharma': 110,
#  'lasith malinga': 200,
#  'mohammad shami': 480,
#  'varun aaron': 240,
#  'mohit sharma': 500,
#  'devdutt padikkal': 20,
#  'anmolpreet singh': 80,
#  'sarfaraz khan': 25,
#  'shivam dube': 500,
#  'varun chakravarthy': 840,
#  'ankush bains': 20,
#  'nathu singh': 20,
#  'colin ingram': 640,
#  'sam curran': 720,
#  'heinrich klaasen': 50,
#  'barinder sran': 340,
#  'lockie ferguson': 160,
#  'sherfane rutherford': 200,
#  'anrich nortje': 20,
#  'oshane thomas': 110,
#  'hardus viljoen': 75,
#  'himmat singh': 65,
#  'nikhil naik': 20,
#  'arshdeep singh': 20,
#  'harry gurney': 75,
#  'pankaj jaiswal': 20,
#  'milind kumar': 20,
#  'darshan nalkande': 30,
#  'shashank singh': 30,
#  'prab simran singh': 480,
#  'rasikh salam': 20,
#  'prithvi raj yarra': 20,
#  'liam livingstone': 50,
#  'keemo paul': 50,
#  'prayas ray barman': 150,
#  'agnivesh ayachi': 20,
#  'harpreet brar': 20,
#  'martin guptill': 100,
#  'yuvraj singh': 100,
#  'akshdeep nath': 360,
#  'jalaj saxena': 20,
#  'murugan ashwin': 20,
#  'ruturaj gaikwad': 20,
#  'shubham ranjane': 20,
#  'joe denly': 100,
#  'bandaru ayyappa': 20,
#  'shrikant mundhe': 20,
#  'manan vohra': 20,
#  'ashton turner': 50,
#  'riyan parag': 20}

# %%
final_list=[]
for i in range(len(batsmen_values)):
    temp=batsmen_values[i]
    name_key=batsmen_values[i][0].lower()
    auction_price=prices_dict.get(name_key,0)
    temp=np.append(temp,auction_price)
    final_list.append(temp)
final_list=np.array(final_list)
final_list
# Out:
# array([['Gautam Gambhir', 10.5, 2.0, 291.5, 29.25, 238.5, 112.305, 0],
#        ['Shikhar Dhawan', 15.0, 2.0, 488.0, 37.535, 369.5, 132.15, 520],
#        ['Suresh Raina', 14.5, 3.0, 443.5, 38.63, 321.5, 138.205, 1100],
#        ['Manish Pandey', 13.0, 3.5, 340.0, 37.655, 277.0, 122.005, 1100],
#        ['Parthiv Patel', 11.0, 0.5, 274.0, 27.64, 201.0, 137.585, 170],
#        ['Rahul Tripathi', 13.0, 1.5, 308.5, 26.515, 217.0, 140.88, 340],
#        ['Robin Uthappa', 14.5, 0.0, 369.5, 25.885, 250.0, 148.775, 640],
#        ['Sanju Samson', 14.5, 0.5, 413.5, 29.535, 296.5, 139.6, 800],
#        ['Kieron Pollard', 12.0, 2.0, 259.0, 24.305, 188.0, 136.245, 540],
#        ['Ajinkya Rahane', 15.0, 1.0, 376.0, 26.96, 318.0, 118.235, 400],
#        ['Rishabh Pant', 14.0, 0.5, 525.0, 39.375, 307.5, 169.605, 800],
#        ['Dinesh Karthik', 14.5, 4.5, 429.5, 42.95, 298.0, 143.575, 740],
#        ['Shreyas Iyer', 13.0, 2.5, 374.5, 35.58, 276.5, 135.835, 700],
#        ['Rohit Sharma', 15.0, 2.0, 309.5, 23.805, 244.0, 127.495, 1500],
#        ['Nitish Rana', 13.5, 1.5, 318.5, 26.825, 248.0, 128.58, 340],
#        ['Manoj Tiwary', 8.5, 2.0, 185.5, 24.03, 140.0, 122.045, 0],
#        ['Brendon McCullum', 8.5, 0.0, 223.0, 25.08, 152.5, 145.655, 0],
#        ['Ben Stokes', 12.0, 1.0, 256.0, 23.965, 191.0, 132.355, 1250],
#        ['Glenn Maxwell', 12.5, 1.5, 239.5, 22.54, 149.5, 157.005, 0],
#        ['Virat Kohli', 12.0, 1.5, 419.0, 39.49, 316.5, 130.66, 1700],
#        ['Aaron Finch', 11.0, 1.0, 216.5, 20.83, 140.0, 150.055, 0],
#        ['Chris Lynn', 11.5, 1.0, 393.0, 40.94499999999999, 270.0,
#         155.605, 960],
#        ['MS Dhoni', 15.0, 6.5, 372.5, 51.095, 276.0, 133.33, 0],
#        ['Karun Nair', 12.5, 0.0, 291.0, 23.345, 223.5, 130.26, 560],
#        ['Ishan Kishan', 11.0, 0.0, 276.0, 25.305, 195.0, 141.955, 620],
#        ['Jos Buttler', 11.5, 1.5, 410.0, 41.0, 265.0, 154.455, 440],
#        ['Kedar Jadhav', 7.0, 1.0, 145.5, 11.125, 104.0, 126.315, 780],
#        ['Kane Williamson', 12.0, 2.0, 495.5, 47.58, 342.5, 146.955, 300],
#        ['Yuvraj Singh', 8.5, 1.0, 158.5, 19.415, 125.0, 115.705, 100],
#        ['Hardik Pandya', 14.5, 6.5, 255.0, 32.295, 177.5, 144.79, 1100],
#        ['Krunal Pandya', 12.0, 3.5, 235.5, 28.755, 168.0, 140.485, 880],
#        ['Wriddhiman Saha', 10.5, 1.5, 178.0, 19.325, 144.5, 122.365, 120],
#        ['Manan Vohra', 6.5, 0.0, 142.0, 19.595, 103.0, 130.52, 20],
#        ['Axar Patel', 10.5, 3.5, 153.5, 20.85, 115.5, 128.03, 500],
#        ['Sunil Narine', 15.0, 0.5, 290.5, 19.77, 159.0, 181.095, 850],
#        ['AB de Villiers', 10.0, 1.5, 348.0, 40.165, 219.0, 153.525, 1100],
#        ['Chris Gayle', 10.0, 1.0, 284.0, 31.55, 207.5, 134.36, 200],
#        ['Mandeep Singh', 11.5, 1.5, 220.0, 22.0, 181.5, 120.845, 140],
#        ['Ravindra Jadeja', 10.0, 5.5, 123.5, 28.65, 93.5, 130.045, 700],
#        ['Chris Morris', 6.5, 3.5, 100.0, 38.4, 60.0, 170.37, 710],
#        ['Pawan Negi', 6.0, 1.0, 73.5, 9.75, 58.0, 94.86, 100],
#        ['Yusuf Pathan', 12.0, 3.5, 201.5, 23.375, 157.5, 127.17, 190],
#        ['Corey Anderson', 7.0, 2.0, 79.5, 12.97, 72.5, 96.35499999999999,
#         0],
#        ['Sam Billings', 7.0, 0.0, 123.0, 18.25, 91.0, 135.575, 100],
#        ['Colin de Grandhomme', 8.5, 2.0, 128.5, 20.975, 88.0, 146.45,
#         220],
#        ['Suryakumar Yadav', 10.5, 0.5, 308.5, 27.035, 236.0, 126.32, 320],
#        ['Vijay Shankar', 7.5, 4.5, 156.5, 51.75, 111.5, 138.95, 320],
#        ['Ambati Rayudu', 10.5, 1.0, 346.5, 30.6, 240.0, 133.205, 220],
#        ['David Miller', 3.5, 1.0, 78.5, 32.33, 72.0, 109.685, 300],
#        ['Naman Ojha', 3.0, 0.5, 40.0, 10.375, 34.5, 73.265, 0],
#        ['Dan Christian', 6.0, 2.5, 52.5, 14.4, 41.0, 120.0, 0],
#        ['Deepak Hooda', 7.0, 3.5, 82.5, 23.875, 66.5, 128.7, 360],
#        ['Stuart Binny', 6.0, 1.0, 61.0, 12.2, 57.5, 107.725, 50],
#        ['Shane Watson', 11.0, 1.0, 313.0, 25.735, 218.5, 122.805, 400],
#        ['Jason Roy', 4.0, 1.0, 89.5, 29.75, 67.0, 137.575, 0],
#        ['Andrew Tye', 5.5, 1.5, 42.5, 15.915, 34.0, 130.435, 720],
#        ['Ben Cutting', 4.5, 1.5, 73.5, 24.75, 42.0, 180.83, 220],
#        ['Mohit Sharma', 5.5, 2.0, 30.5, 9.25, 31.5, 89.46000000000001,
#         500],
#        ['Amit Mishra', 3.5, 3.0, 25.0, 24.5, 27.0, 72.11500000000001,
#         400],
#        ['Chris Woakes', 5.5, 2.5, 31.5, 10.0, 33.0, 93.67, 0],
#        ['Mohammad Shami', 3.5, 1.0, 21.5, 8.0, 15.0, 133.33, 480],
#        ['Basil Thampi', 3.5, 3.0, 15.5, 1.5, 17.0, 75.0, 95],
#        ['Mayank Agarwal', 7.0, 0.5, 73.0, 10.33, 60.5, 111.97, 100],
#        ['Kuldeep Yadav', 2.5, 1.0, 16.0, 11.0, 23.0, 70.45, 580],
#        ['Mitchell Johnson', 2.5, 2.5, 18.0, 0.0, 14.0, 131.545, 0],
#        ['Rahul Tewatia', 3.5, 1.5, 34.5, 17.83, 27.0, 144.495, 300],
#        ['Marcus Stoinis', 5.0, 1.5, 58.0, 15.205, 50.0, 100.545, 620],
#        ['Mitchell McClenaghan', 6.0, 3.0, 13.5, 4.75, 12.5, 108.33, 100],
#        ['Harbhajan Singh', 5.0, 2.5, 22.5, 8.83, 26.0, 90.275, 200],
#        ['Jasprit Bumrah', 2.5, 1.5, 13.0, 13.0, 11.5, 112.115, 700],
#        ['Anureet Singh', 1.0, 0.5, 9.0, 7.5, 8.0, 100.0, 0],
#        ['Deepak Chahar', 2.5, 0.5, 32.0, 15.33, 17.5, 202.87, 80],
#        ['Yuzvendra Chahal', 3.5, 2.0, 6.5, 2.165, 15.0, 25.0, 600],
#        ['Carlos Brathwaite', 3.0, 0.5, 43.5, 15.5, 31.5, 118.125, 500],
#        ['Rashid Khan', 5.0, 1.5, 35.0, 8.65, 20.0, 156.27, 900],
#        ['Umesh Yadav', 4.5, 2.5, 6.5, 0.375, 12.0, 52.095, 420],
#        ['Washington Sundar', 5.5, 3.5, 37.0, 15.33, 25.0, 123.025, 320],
#        ['Faf du Plessis', 3.5, 0.5, 85.0, 20.2, 68.0, 119.93, 160],
#        ['Tim Southee', 2.5, 1.0, 29.5, 16.5, 24.5, 173.185, 100],
#        ['Sandeep Sharma', 3.5, 2.5, 3.5, 0.0, 5.0, 58.33, 300],
#        ['Trent Boult', 1.0, 0.5, 2.5, 0.0, 5.0, 31.25, 220],
#        ['Bhuvneshwar Kumar', 3.0, 1.5, 8.5, 5.25, 10.0, 90.625, 850],
#        ['Ankit Rajpoot', 2.0, 0.0, 7.5, 3.83, 12.5, 59.125, 300],
#        ['Shahbaz Nadeem', 2.5, 1.0, 4.0, 0.33, 8.5, 48.61, 320],
#        ['Jaydev Unadkat', 4.5, 2.5, 25.5, 6.125, 21.5, 84.47, 840],
#        ['Mohammad Nabi', 1.5, 0.0, 10.0, 5.5, 7.5, 108.33, 100],
#        ['Piyush Chawla', 4.0, 1.5, 14.5, 4.375, 20.0, 56.37, 420],
#        ['Pradeep Sangwan', 2.0, 0.5, 1.0, 0.5, 4.0, 25.0, 0],
#        ['Dhawal Kulkarni', 1.5, 0.5, 3.5, 3.5, 4.5, 67.85499999999999,
#         75],
#        ['Shakib Al Hasan', 7.0, 1.5, 120.0, 10.86, 99.0, 110.655, 200],
#        ['Shardul Thakur', 2.0, 0.5, 7.5, 0.0, 4.0, 150.0, 260],
#        ['Siddarth Kaul', 2.5, 1.0, 1.5, 0.5, 8.0, 10.71, 380],
#        ['Akshdeep Nath', 1.0, 0.0, 4.5, 4.5, 7.0, 34.615, 360],
#        ['Imran Tahir', 1.0, 1.0, 1.0, 0.0, 2.0, 50.0, 100]], dtype=object)

# %%
batsmen_final_list=pd.DataFrame(final_list,columns=['Player','Inns','NO','Runs','Avg','BF','SR','Price'])

# %%
final_list=[]
for i in range(len(bowlers_values)):
    temp=bowlers_values[i]
    name_key=bowlers_values[i][0].lower()
    auction_price=prices_dict.get(name_key,0)
    temp=np.append(temp,auction_price)
    final_list.append(temp)
final_list=np.array(final_list)
final_list
# Out:
# array([['Bhuvneshwar Kumar', 49.15000000000001, 17.5, 26.76, 7.355,
#         21.42, 850],
#        ['Jaydev Unadkat', 47.85, 17.5, 28.795, 8.335, 19.45, 840],
#        ['Jasprit Bumrah', 56.6, 18.5, 21.915, 7.135, 18.425, 700],
#        ['Mitchell McClenaghan', 47.0, 16.5, 25.195, 8.84, 17.095, 100],
#        ['Imran Tahir', 33.7, 12.0, 25.915, 8.469999999999999, 18.16, 100],
#        ['Rashid Khan', 61.0, 19.0, 21.425, 6.675000000000001, 19.235,
#         900],
#        ['Sandeep Sharma', 46.0, 14.5, 25.58, 7.924999999999999, 19.47,
#         300],
#        ['Umesh Yadav', 50.7, 18.5, 22.505, 8.155, 16.53, 420],
#        ['Chris Woakes', 31.1, 12.5, 23.225, 9.565, 14.635, 0],
#        ['Pawan Negi', 18.05, 8.5, 30.655, 9.185, 18.03, 100],
#        ['Siddarth Kaul', 50.7, 18.5, 22.395, 8.344999999999999, 16.11,
#         380],
#        ['Axar Patel', 37.0, 9.0, 48.395, 7.960000000000001, 35.6, 500],
#        ['Yuzvendra Chahal', 46.65, 13.0, 27.015, 7.455, 21.82, 600],
#        ['Karn Sharma', 19.85, 8.5, 19.355, 8.165, 14.2, 500],
#        ['Mohit Sharma', 37.4, 10.0, 38.765, 9.91, 23.245, 500],
#        ['Andrew Tye', 38.5, 18.0, 15.205, 7.355, 12.25, 720],
#        ['Ben Stokes', 40.5, 10.0, 32.09999999999999, 7.68, 24.875, 1250],
#        ['Chris Morris', 22.5, 7.5, 33.83, 8.975000000000001, 21.75, 710],
#        ['Kuldeep Yadav', 46.1, 14.5, 26.455, 8.215, 19.305, 580],
#        ['Dan Christian', 25.75, 7.5, 26.17, 7.99, 19.78, 0],
#        ['Shardul Thakur', 42.25, 13.5, 27.78, 8.74, 19.155, 260],
#        ['Basil Thampi', 27.25, 8.0, 30.67, 10.35, 18.28, 95],
#        ['Krunal Pandya', 40.05, 11.0, 25.48, 6.945, 22.04, 880],
#        ['Sunil Narine', 60.0, 13.5, 34.335, 7.315, 28.46, 850],
#        ['Amit Mishra', 37.75, 11.0, 28.15, 7.98, 20.9, 400],
#        ['Mohammed Siraj', 32.0, 10.5, 27.28, 9.08, 18.08, 260],
#        ['Washington Sundar', 25.0, 6.0, 35.56, 7.88, 26.25, 320],
#        ['Harbhajan Singh', 36.25, 7.5, 35.91, 7.48, 29.015, 200],
#        ['Glenn Maxwell', 17.5, 6.0, 22.125, 7.41, 17.74, 0],
#        ['Mitchell Johnson', 20.5, 4.5, 64.07, 8.665, 40.07, 0],
#        ['Shahbaz Nadeem', 16.25, 4.5, 36.745, 8.7, 23.915, 320],
#        ['Hardik Pandya', 34.2, 12.0, 28.33, 8.555, 20.11, 1100],
#        ['Piyush Chawla', 34.5, 10.0, 29.625, 8.675, 20.5, 420],
#        ['Trent Boult', 37.95, 11.5, 34.54, 8.95, 23.075, 220],
#        ['Shane Watson', 27.25, 5.5, 45.415, 9.045000000000002, 30.1, 400],
#        ['Ravindra Jadeja', 39.5, 8.0, 48.67, 8.285, 33.98, 700],
#        ['Mohammad Shami', 19.75, 4.0, 48.3, 9.870000000000001, 29.43,
#         480],
#        ['Pradeep Sangwan', 10.0, 2.5, 18.1, 9.775, 10.8, 0],
#        ['Ankit Rajpoot', 20.05, 7.5, 23.51, 8.08, 17.635, 300],
#        ['Stuart Binny', 4.0, 2.0, 6.25, 12.415, 4.5, 50],
#        ['Colin de Grandhomme', 15.5, 3.0, 49.125, 8.515, 34.5, 220],
#        ['Rahul Tewatia', 15.5, 4.5, 22.58, 6.65, 20.0, 300],
#        ['Dhawal Kulkarni', 19.0, 3.5, 52.33, 9.325, 33.705, 75],
#        ['Tim Southee', 19.5, 4.0, 42.1, 9.3, 27.4, 100],
#        ['Corey Anderson', 13.45, 3.0, 50.165, 11.565, 27.495, 0],
#        ['Harshal Patel', 10.65, 5.0, 19.09, 10.145, 11.5, 20],
#        ['Mohammad Nabi', 8.0, 1.5, 38.0, 7.335, 31.5, 100],
#        ['Billy Stanlake', 12.0, 3.5, 30.5, 8.434999999999999, 21.6, 50],
#        ['Vinay Kumar', 3.25, 2.0, 24.0, 13.64, 10.25, 0],
#        ['Marcus Stoinis', 10.65, 2.5, 47.5, 10.685, 26.75, 620],
#        ['Deepak Hooda', 3.5, 1.0, 10.5, 9.25, 6.0, 360],
#        ['Avesh Khan', 11.5, 2.5, 37.0, 8.24, 26.25, 70],
#        ['Chris Jordan', 2.5, 0.5, 4.5, 8.375, 3.0, 0],
#        ['Ben Cutting', 14.7, 1.5, 103.5, 9.795000000000002, 63.5, 220],
#        ['Yusuf Pathan', 3.0, 1.0, 27.5, 8.625, 18.0, 190],
#        ['Deepak Chahar', 22.55, 5.5, 50.9, 8.925, 32.45, 80],
#        ['Yuvraj Singh', 2.0, 0.5, 11.0, 11.25, 6.0, 100],
#        ['Carlos Brathwaite', 8.05, 3.0, 42.9, 10.2, 24.1, 500],
#        ['Shakib Al Hasan', 30.0, 7.0, 16.285, 9.165, 12.21, 200],
#        ['Mustafizur Rahman', 14.85, 3.5, 16.425, 10.555, 11.785, 0],
#        ['Anureet Singh', 3.0, 0.5, 21.0, 11.75, 12.0, 0],
#        ['Barinder Sran', 12.0, 2.0, 28.625, 12.45, 16.5, 340],
#        ['Ankit Sharma', 1.0, 0.0, 0.0, 13.5, 0.0, 0]], dtype=object)

# %%
bowlers_final_list=pd.DataFrame(final_list,columns=['Player','Ov','Wkts','Avg','Econ','SR','Price'])

# %%
import xlsxwriter
writer = pd.ExcelWriter('../final_dataset_merged_v2.xlsx', engine='xlsxwriter')
batsmen_final_list.to_excel(writer, sheet_name='Batsmen',index=False)
bowlers_final_list.to_excel(writer, sheet_name='Bowlers',index=False)
writer.save()
