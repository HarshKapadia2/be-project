# %%
import pandas as pd
import numpy as np

# %%
dataset_bowlers = pd.read_excel('dataset_2019.xlsx','Bowlers')
dataset_batsmen = pd.read_excel('dataset_2019.xlsx','Batsmen')
dataset_auction = pd.read_excel('dataset_2019.xlsx','Auction')

# %%
auction_names=dataset_auction.iloc[:,0].values
auction_values=dataset_auction.iloc[:,1].values

batsmen_values=dataset_batsmen.iloc[:,:].values
bowlers_values=dataset_bowlers.iloc[:,:].values

# %%
prices_dict={auction_names[i]:auction_values[i] for i in range(len(auction_names))}
prices_dict
# Out:
# {'Quinton de Kock': 280,
#  'Mandeep Singh': 140,
#  'Marcus Stoinis': 620,
#  'Shikhar Dhawan': 520,
#  'Vijay Shankar': 320,
#  'Shahbaz Nadeem': 320,
#  'Abhishek Sharma': 55,
#  'Mahendra Singh Dhoni': 1500,
#  'Suresh Raina': 1100,
#  'Kedar Jadhav': 780,
#  'Ravindra Jadeja': 700,
#  'Dwayne Bravo': 640,
#  'Karn Sharma': 500,
#  'Shane Watson': 400,
#  'Shardul Thakur': 260,
#  'Ambati Rayudu': 220,
#  'David Willey[REP]': 200,
#  'Harbhajan Singh': 200,
#  'Murali Vijay': 200,
#  'Faf du Plessis': 160,
#  'Imran Tahir': 100,
#  'Sam Billings': 100,
#  'Deepak Chahar': 80,
#  'Lungi Ngidi': 50,
#  'Mitchell Santner': 50,
#  'KM Asif': 40,
#  'Chaitanya Bishnoi': 20,
#  'Dhruv Shorey': 20,
#  'Monu Singh': 20,
#  'Narayan Jagadeesan': 20,
#  'Rishabh Pant': 800,
#  'Chris Morris': 710,
#  'Shreyas Iyer': 700,
#  'Kagiso Rabada': 420,
#  'Amit Mishra': 400,
#  'Rahul Tewatia': 300,
#  'Trent Boult': 220,
#  'Colin Munro': 190,
#  'Prithvi Shaw': 120,
#  'Avesh Khan': 70,
#  'Jayant Yadav[TRA]': 50,
#  'Harshal Patel': 20,
#  'Manjot Kalra': 20,
#  'Sandeep Lamichhane': 20,
#  'KL Rahul': 1100,
#  'Ravichandran Ashwin': 760,
#  'Andrew Tye': 720,
#  'Karun Nair': 560,
#  'Mujeeb Ur Rahman': 400,
#  'Ankit Rajpoot': 300,
#  'David Miller': 300,
#  'Chris Gayle': 200,
#  'Mayank Agarwal': 100,
#  'Sunil Narine': 850,
#  'Chris Lynn': 960,
#  'Andre Russell': 700,
#  'Dinesh Karthik': 740,
#  'Robin Uthappa': 640,
#  'Kuldeep Yadav': 580,
#  'Piyush Chawla': 420,
#  'Nitish Rana': 340,
#  'Kamlesh Nagarkoti': 320,
#  'Shivam Mavi': 300,
#  'Shubman Gill': 180,
#  'Rinku Singh': 80,
#  'Prasidh Krishna': 20,
#  'Rohit Sharma': 1500,
#  'Hardik Pandya': 1100,
#  'Krunal Pandya': 880,
#  'Jasprit Bumrah': 700,
#  'Ishan Kishan': 620,
#  'Kieron Pollard': 540,
#  'Evin Lewis': 380,
#  'Suryakumar Yadav': 320,
#  'Ben Cutting': 220,
#  'Rahul Chahar': 190,
#  'Jason Behrendorff': 150,
#  'Mitchell McClenaghan': 100,
#  'Adam Milne': 75,
#  'Aditya Tare': 20,
#  'Anukul Roy': 20,
#  'Mayank Markande': 20,
#  'Siddhesh Lad': 20,
#  'Ben Stokes': 1250,
#  'Steve Smith': 1200,
#  'Sanju Samson': 800,
#  'Jofra Archer': 720,
#  'Krishnappa Gowtham': 620,
#  'Jos Buttler': 440,
#  'Ajinkya Rahane': 400,
#  'Rahul Tripathi': 340,
#  'Dhawal Kulkarni': 75,
#  'Ish Sodhi': 50,
#  'Stuart Binny': 50,
#  'Aryaman Birla': 30,
#  'Mahipal Lomror': 20,
#  'Prashant Chopra': 20,
#  'Shreyas Gopal': 20,
#  'Sudhesan Midhun': 20,
#  'Virat Kohli': 1700,
#  'AB de Villiers': 1100,
#  'Yuzvendra Chahal': 600,
#  'Umesh Yadav': 420,
#  'Washington Sundar': 320,
#  'Navdeep Saini': 300,
#  'Mohammed Siraj': 260,
#  'Colin de Grandhomme': 220,
#  'Nathan Coulter-Nile': 220,
#  'Moeen Ali': 170,
#  'Parthiv Patel': 170,
#  'Pawan Negi': 100,
#  'Tim Southee': 100,
#  'Kulwant Khejroliya': 85,
#  'David Warner': 1200,
#  'Manish Pandey': 1100,
#  'Rashid Khan': 900,
#  'Bhuvneshwar Kumar': 850,
#  'Siddarth Kaul': 380,
#  'Deepak Hooda': 360,
#  'Kane Williamson': 300,
#  'Khaleel Ahmed': 300,
#  'Sandeep Sharma': 300,
#  'Shakib Al Hasan': 200,
#  'Yusuf Pathan': 190,
#  'Mohammad Nabi': 100,
#  'Shreevats Goswami': 100,
#  'Basil Thampi': 95,
#  'Billy Stanlake': 50,
#  'Thangarasu Natarajan': 40,
#  'Ricky Bhui': 20,
#  'Hanuma Vihari': 200,
#  'Shimron Hetmyer': 420,
#  'Carlos Brathwaite': 500,
#  'Gurkeerat Singh': 50,
#  'Moises Henriques': 100,
#  'Axar Patel': 500,
#  'Jonny Bairstow': 220,
#  'Nicholas Pooran': 420,
#  'Wriddhiman Saha': 120,
#  'Jaydev Unadkat': 840,
#  'Ishant Sharma': 110,
#  'Lasith Malinga': 200,
#  'Mohammad Shami': 480,
#  'Varun Aaron': 240,
#  'Mohit Sharma': 500,
#  'Devdutt Padikkal': 20,
#  'Anmolpreet Singh': 80,
#  'Sarfaraz Khan': 25,
#  'Shivam Dube': 500,
#  'Varun Chakravarthy': 840,
#  'Ankush Bains': 20,
#  'Nathu Singh': 20,
#  'Colin Ingram': 640,
#  'Sam Curran': 720,
#  'Heinrich Klaasen': 50,
#  'Barinder Sran': 340,
#  'Lockie Ferguson': 160,
#  'Sherfane Rutherford[ACC]': 200,
#  'Anrich Nortje[ACC]': 20,
#  'Oshane Thomas[ACC]': 110,
#  'Hardus Viljoen[ACC]': 75,
#  'Himmat Singh[ACC]': 65,
#  'Nikhil Naik[ACC]': 20,
#  'Arshdeep Singh[ACC]': 20,
#  'Harry Gurney[ACC]': 75,
#  'Pankaj Jaiswal[ACC]': 20,
#  'Milind Kumar[ACC]': 20,
#  'Darshan Nalkande[ACC]': 30,
#  'Shashank Singh[ACC]': 30,
#  'Prab Simran Singh[ACC]': 480,
#  'Rasikh Salam[ACC]': 20,
#  'Prithvi Raj Yarra[ACC]': 20,
#  'Liam Livingstone[ACC]': 50,
#  'Keemo Paul[ACC]': 50,
#  'Prayas Ray Barman[ACC]': 150,
#  'Agnivesh Ayachi[ACC]': 20,
#  'Harpreet Brar[ACC]': 20,
#  'Martin Guptill[REC-1]': 100,
#  'Yuvraj Singh[REC-1]': 100,
#  'Akshdeep Nath[REC-1]': 360,
#  'Jalaj Saxena[REC-2]': 20,
#  'Murugan Ashwin[REC-2]': 20,
#  'Ruturaj Gaikwad[DI-REC-2]': 20,
#  'Shubham Ranjane[ACC][REC-2]': 20,
#  'Joe Denly[ACC][REC-2]': 100,
#  'Bandaru Ayyappa[DI-REC-2]': 20,
#  'Shrikant Mundhe[ACC][REC-2]': 20,
#  'Manan Vohra[REC-3]': 20,
#  'Ashton Turner[ACC][REC-3]': 50,
#  'Riyan Parag[DI-REC-3]': 20}

# %%
final_list=[]
for i in range(len(batsmen_values)):
    temp=batsmen_values[i]
    name_key=batsmen_values[i][0]
    auction_price=prices_dict.get(name_key,0)
    temp=np.append(temp,auction_price)
    final_list.append(temp)
final_list=np.array(final_list)
final_list
# Out:
# array([['David Warner', 12, 2, ..., 481, 143.86, 1200],
#        ['KL Rahul', 14, 3, ..., 438, 135.38, 1100],
#        ['Quinton de Kock', 16, 1, ..., 398, 132.91, 280],
#        ...,
#        ['Sam Billings', 1, 0, ..., 4, 0.0, 100],
#        ['Prithvi Raj Yarra', 1, 1, ..., 1, 0.0, 0],
#        ['Mujeeb Ur Rahman', 3, 2, ..., 4, 0.0, 400]], dtype=object)

# %%
batsmen_final_list=pd.DataFrame(final_list,columns=['Player','Inns','NO','Runs','Avg','BF','SR','Price'])

# %%
final_list=[]
for i in range(len(bowlers_values)):
    temp=bowlers_values[i]
    name_key=bowlers_values[i][0]
    auction_price=prices_dict.get(name_key,0)
    temp=np.append(temp,auction_price)
    final_list.append(temp)
final_list=np.array(final_list)
final_list
# Out:
# array([['Kagiso Rabada', 47.0, 25, 14.72, 7.82, 11.28, 420],
#        ['Deepak Chahar', 64.3, 22, 21.9, 7.47, 17.59, 80],
#        ['Shreyas Gopal', 48.0, 20, 17.35, 7.22, 14.4, 20],
#        ['Jasprit Bumrah', 61.4, 19, 21.52, 6.63, 19.47, 700],
#        ['Khaleel Ahmed', 34.5, 19, 15.1, 8.23, 11.0, 300],
#        ['Mohammad Shami', 54.0, 19, 24.68, 8.68, 17.05, 480],
#        ['Yuzvendra Chahal', 49.2, 18, 21.44, 7.82, 16.44, 600],
#        ['Rashid Khan', 60.0, 17, 22.17, 6.28, 21.17, 900],
#        ['Harbhajan Singh', 44.0, 16, 19.5, 7.09, 16.5, 200],
#        ['Lasith Malinga', 44.5, 16, 27.37, 9.76, 16.81, 200],
#        ['Ravindra Jadeja', 54.0, 15, 22.86, 6.35, 21.6, 700],
#        ['Ravichandran Ashwin', 55.0, 15, 26.66, 7.27, 22.0, 760],
#        ['Hardik Pandya', 42.3, 14, 27.85, 9.17, 18.21, 1100],
#        ['Rahul Chahar', 47.0, 13, 23.69, 6.55, 21.69, 190],
#        ['Ishant Sharma', 46.0, 13, 26.84, 7.58, 21.23, 110],
#        ['Bhuvneshwar Kumar', 59.0, 13, 35.46, 7.81, 27.23, 850],
#        ['Chris Morris', 33.0, 13, 23.53, 9.27, 15.23, 710],
#        ['Krunal Pandya', 46.0, 12, 27.91, 7.28, 23.0, 880],
#        ['Sandeep Sharma', 42.4, 12, 29.33, 8.25, 21.33, 300],
#        ['Amit Mishra', 40.0, 11, 24.54, 6.75, 21.81, 400],
#        ['Jofra Archer', 43.0, 11, 26.45, 6.76, 23.45, 720],
#        ['Dwayne Bravo', 41.1, 11, 30.0, 8.01, 22.45, 640],
#        ['Navdeep Saini', 48.0, 11, 36.09, 8.27, 26.18, 300],
#        ['Andre Russell', 30.1, 11, 26.09, 9.51, 16.45, 700],
#        ['Axar Patel', 51.0, 10, 36.4, 7.13, 30.6, 500],
#        ['Sunil Narine', 44.2, 10, 34.7, 7.82, 26.6, 850],
#        ['Piyush Chawla', 44.3, 10, 39.9, 8.96, 26.7, 420],
#        ['Sam Curran', 33.0, 10, 32.3, 9.78, 19.8, 720],
#        ['Jaydev Unadkat', 37.2, 10, 39.8, 10.66, 22.4, 840],
#        ['Keemo Paul', 27.1, 9, 26.33, 8.72, 18.11, 0],
#        ['Mohammad Nabi', 29.1, 8, 24.25, 6.65, 21.87, 100],
#        ['Sandeep Lamichhane', 23.0, 8, 26.25, 9.13, 17.25, 20],
#        ['Shardul Thakur', 30.0, 8, 35.12, 9.36, 22.5, 260],
#        ['Umesh Yadav', 37.5, 8, 46.37, 9.8, 28.37, 420],
#        ['Harry Gurney', 27.0, 7, 34.0, 8.81, 23.14, 0],
#        ['Mohammed Siraj', 28.1, 7, 38.42, 9.55, 24.14, 260],
#        ['Hardus Viljoen', 23.0, 7, 31.71, 9.65, 19.71, 0],
#        ['Moeen Ali', 25.0, 6, 28.16, 6.76, 25.0, 170],
#        ['Siddarth Kaul', 27.0, 6, 40.33, 8.96, 27.0, 380],
#        ['Dhawal Kulkarni', 35.0, 6, 55.83, 9.57, 35.0, 75],
#        ['Alzarri Joseph', 8.4, 6, 14.5, 10.03, 8.66, 0],
#        ['Ben Stokes', 16.5, 6, 31.5, 11.22, 16.83, 1250],
#        ['Murugan Ashwin', 34.0, 5, 51.0, 7.5, 40.8, 0],
#        ['Oshane Thomas', 10.0, 5, 15.8, 7.9, 12.0, 0],
#        ['Trent Boult', 19.0, 5, 32.6, 8.57, 22.8, 220],
#        ['Jason Behrendorff', 19.0, 5, 33.0, 8.68, 22.8, 150],
#        ['Mitchell Santner', 14.0, 4, 23.5, 6.71, 21.0, 50],
#        ['Washington Sundar', 9.0, 4, 18.5, 8.22, 13.5, 320],
#        ['Dale Steyn', 8.0, 4, 17.25, 8.62, 12.0, 0],
#        ['Kuldeep Yadav', 33.0, 4, 71.5, 8.66, 49.5, 580],
#        ['Prasidh Krishna', 40.2, 4, 94.25, 9.34, 60.5, 20],
#        ['Ish Sodhi', 7.1, 4, 16.75, 9.34, 10.75, 50],
#        ['Varun Aaron', 12.0, 4, 29.0, 9.66, 18.0, 240],
#        ['Mitchell McClenaghan', 18.0, 3, 47.33, 7.88, 36.0, 100],
#        ['Nitish Rana', 8.0, 3, 24.0, 9.0, 16.0, 340],
#        ['Pawan Negi', 11.1, 3, 34.0, 9.13, 22.33, 100],
#        ['Ankit Rajpoot', 16.0, 3, 50.66, 9.5, 32.0, 300],
#        ['Mujeeb Ur Rahman', 19.0, 3, 63.66, 10.05, 38.0, 400],
#        ['Andrew Tye', 22.0, 3, 77.66, 10.59, 44.0, 720],
#        ['Arshdeep Singh', 10.0, 3, 36.33, 10.9, 20.0, 0],
#        ['Rahul Tewatia', 6.2, 2, 21.0, 6.63, 19.0, 300],
#        ['Jagadeesha Suchith', 4.0, 2, 14.0, 7.0, 12.0, 0],
#        ['Sandeep Warrier', 12.0, 2, 42.5, 7.08, 36.0, 0],
#        ['Riyan Parag', 14.0, 2, 60.5, 8.64, 42.0, 0],
#        ['Marcus Stoinis', 16.4, 2, 72.5, 8.7, 50.0, 620],
#        ['Shakib Al Hasan', 10.5, 2, 47.5, 8.76, 32.5, 200],
#        ['Scott Kuggeleijn', 8.0, 2, 35.5, 8.87, 24.0, 0],
#        ['Harshal Patel', 8.0, 2, 38.5, 9.62, 24.0, 20],
#        ['Shahbaz Nadeem', 9.0, 2, 45.0, 10.0, 27.0, 320],
#        ['Lockie Ferguson', 17.0, 2, 91.5, 10.76, 51.0, 160],
#        ['Anukul Roy', 2.0, 1, 11.0, 5.5, 12.0, 20],
#        ['Stuart Binny', 7.0, 1, 44.0, 6.28, 42.0, 50],
#        ['Jayant Yadav', 7.0, 1, 50.0, 7.14, 42.0, 0],
#        ['Krishnappa Gowtham', 20.0, 1, 166.0, 8.3, 120.0, 620],
#        ['Sherfane Rutherford', 6.5, 1, 59.0, 8.63, 41.0, 0],
#        ['Vijay Shankar', 8.0, 1, 70.0, 8.75, 48.0, 320],
#        ['Mohit Sharma', 3.0, 1, 27.0, 9.0, 18.0, 500],
#        ['Kulwant Khejroliya', 5.0, 1, 47.0, 9.4, 30.0, 85],
#        ['Mayank Markande', 6.0, 1, 59.0, 9.83, 36.0, 20],
#        ['Deepak Hooda', 2.0, 1, 21.0, 10.5, 12.0, 360],
#        ['Abhishek Sharma', 2.0, 1, 21.0, 10.5, 12.0, 55],
#        ['Prithvi Raj Yarra', 5.0, 1, 57.0, 11.4, 30.0, 0],
#        ['Karn Sharma', 2.5, 1, 33.0, 11.64, 17.0, 500],
#        ['Varun Chakaravarthy', 3.0, 1, 35.0, 11.66, 18.0, 0],
#        ['Tim Southee', 9.0, 1, 118.0, 13.11, 54.0, 100],
#        ['Ben Cutting', 2.0, 1, 27.0, 13.5, 12.0, 220],
#        ['Shivam Dube', 1.4, 0, 0.0, 4.8, 0.0, 500],
#        ['Suresh Raina', 1.0, 0, 0.0, 6.0, 0.0, 1100],
#        ['Yusuf Pathan', 1.0, 0, 0.0, 8.0, 0.0, 190],
#        ['Hanuma Vihari', 1.0, 0, 0.0, 9.0, 0.0, 200],
#        ['Basil Thampi', 12.0, 0, 0.0, 9.16, 0.0, 95],
#        ['Harpreet Brar', 5.0, 0, 0.0, 9.6, 0.0, 0],
#        ['Carlos Brathwaite', 3.0, 0, 0.0, 9.66, 0.0, 500],
#        ['Avesh Khan', 3.0, 0, 0.0, 10.0, 0.0, 70],
#        ['Rasikh Salam', 4.0, 0, 0.0, 10.5, 0.0, 0],
#        ['Colin de Grandhomme', 5.0, 0, 0.0, 11.0, 0.0, 220],
#        ['Barinder Sran', 4.0, 0, 0.0, 12.75, 0.0, 340],
#        ['Liam Livingstone', 1.0, 0, 0.0, 13.0, 0.0, 0],
#        ['Mandeep Singh', 2.0, 0, 0.0, 13.0, 0.0, 140],
#        ['Sudhesan Midhun', 2.0, 0, 0.0, 13.5, 0.0, 20],
#        ['Prayas Ray Barman', 4.0, 0, 0.0, 14.0, 0.0, 0],
#        ['KC Cariappa', 2.0, 0, 0.0, 17.0, 0.0, 0],
#        ['Sarfaraz Khan', 0.2, 0, 0.0, 18.0, 0.0, 25]], dtype=object)

# %%
bowlers_final_list=pd.DataFrame(final_list,columns=['Player','Ov','Wkts','Avg','Econ','SR','Price'])

# %%
import xlsxwriter
writer = pd.ExcelWriter('final_dataset_2019_v2.xlsx', engine='xlsxwriter')
batsmen_final_list.to_excel(writer, sheet_name='Batsmen',index=False)
bowlers_final_list.to_excel(writer, sheet_name='Bowlers',index=False)
writer.save()
